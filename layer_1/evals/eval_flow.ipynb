# %%
import sys
import os

project_root = os.path.abspath("..")

if project_root not in sys.path:
    sys.path.append(project_root)

from mock_builder import build_mock_ticket
from run_evals import run_layer_1_evals

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Shiwan\OneDrive\Desktop\multi_agent_customer_support_system\layer_1\evals

# %%
import os
print(os.listdir())
# Out:
# ['eval_flow.ipynb', 'golden_dataset.json', 'mock_builder.py', 'run_evals.py', '__pycache__']

# %%
run_layer_1_evals()
# Out:
# INFO:eval_runner:Running Evaluation on 6 cases.
# INFO:supervisor_node:Ticket TC-ORCH-001 | Processing Attempt 1
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:parser:Successfully parsed LLM JSON response.
# INFO:supervisor_node:Route Success: refund_agent for ticket TC-ORCH-001
# INFO:supervisor_node:Ticket TC-METADATA-002 | Processing Attempt 1
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:parser:Successfully parsed LLM JSON response.
# INFO:supervisor_node:Route Success: escalation_agent for ticket TC-METADATA-002
# INFO:supervisor_node:Ticket TC-CLARIFY-003 | Processing Attempt 1
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:parser:Successfully parsed LLM JSON response.
# INFO:supervisor_node:Route Success: clarification_flow for ticket TC-CLARIFY-003
# ...

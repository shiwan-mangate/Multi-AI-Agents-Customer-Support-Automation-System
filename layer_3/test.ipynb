# %%
from layer_3.detection.language_detector import LanguageDetector

# This will trigger the __init__ and load the model we just downloaded
detector = LanguageDetector()

# Let's test a Hinglish sentence (which should trigger the consensus logic)
result = detector.detect("Mera refund kab aayega bro")
print(result)
exit()
# Out:
# detected_language='en' confidence=0.5714262607791507 detection_method='weak_signal' script_detected='latin' mixed_language_detected=False raw_detector_results={'fasttext': {'lang': 'unknown', 'confidence': 0.0}, 'langdetect': {'lang': 'so', 'confidence': 0.5714262607791507}}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
